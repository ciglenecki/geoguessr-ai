# %%
api_key = 'AIzaSyCQN2VXF2G2rvGdO55HpCAj8iWBc8sPh_M'

# %%
pic_base = 'https://maps.googleapis.com/maps/api/streetview?'

# %%
# 0 => id
# 1 => long
# 2 => lat
# 3 => is_found
# 4 => true_long
# 5 => true_lat
# 6 => pano_id

# %%
import csv

csv_filepath = "coords_sample__n_1000000.csv"

coords = []

with open(csv_filepath) as f:
    reader = csv.reader(f, delimiter=',')
    next(reader)    # skip header
    for row in reader:
        coords.append(row)

# %%
test_coords = coords[:5]

# %%
test_coords
# Out:
# [['5', '16.640731441473815', '45.6776714091558'],
#  ['9', '18.67219055470197', '45.601193807985766'],
#  ['14', '15.969863116685294', '44.56439677506237'],
#  ['20', '16.10520160056752', '43.895854173394596'],
#  ['21', '13.86515235287547', '45.25963036552755']]

# %%
import requests

def get_metadata(coord, radius):
    meta_base = 'https://maps.googleapis.com/maps/api/streetview/metadata?'
    meta_params = {
        'key': api_key,
        'location': f"{coord[2]},{coord[1]}",
        'radius': radius,
        'return_error_code': 'true',
    }
    meta_response = requests.get(meta_base, params=meta_params)
    return meta_response.json()

# %%
resp_pos = get_metadata(test_coords[0], 5000)
resp_pos
# Out:
# {'copyright': '© Google',
#  'date': '2011-09',
#  'location': {'lat': 45.683551882628, 'lng': 16.61891551756206},
#  'pano_id': 'D0JEts6s7WCqZyCc3aCSwA',
#  'status': 'OK'}

# %%
resp_pos['location']['lng']
# Out:
# 16.61891551756206

# %%
resp_neg = get_metadata(test_coords[0], 1)
resp_neg
# Out:
# {'status': 'ZERO_RESULTS'}

# %%
pano_ids = set()

# %%
pano_ids = set()

results = []

dataset = coords[:1000]

try:
    for coord in dataset:
        response = get_metadata(coord = coord, radius=1000)

        if response.get('status') == 'OK':
            results.append([
                coord[0],
                coord[1],
                coord[2],
                True,
                response['location']['lng'],
                response['location']['lat'],
                response['pano_id'],
            ])
        elif (not response.get('status')) or (response.get('status') == 'ZERO_RESULTS'):
            results.append([
                coord[0],
                coord[1],
                coord[2],
                False,
                None,
                None,
                None,
            ])
        else:
            print(response)
except KeyboardInterrupt:
    last_coord_idx = dataset.index(coord)
    with open("results.csv" , 'a', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(('id', 'long', 'lat', 'is_found', 'true_long', 'true_lat', 'pano_id'))
        for row in results:
            writer.writerow(row)

# %%
with open("results.csv" , 'a', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(('id', 'long', 'lat', 'is_found', 'true_long', 'true_lat', 'pano_id'))
    for row in results:
        writer.writerow(row)

# %%
dataset.index(coord)
# Out:
# 35

# %%
get_metadata(coords[0], 1000)
# Out:
# {'error_message': 'You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started',
#  'status': 'REQUEST_DENIED'}

# %%
results
# Out:
# [['5', '16.640731441473815', '45.6776714091558', False, None, None, None],
#  ['9', '18.67219055470197', '45.601193807985766', False, None, None, None],
#  ['14', '15.969863116685294', '44.56439677506237', False, None, None, None],
#  ['20', '16.10520160056752', '43.895854173394596', False, None, None, None],
#  ['21', '13.86515235287547', '45.25963036552755', False, None, None, None],
#  ['22', '17.47708700277838', '45.158666472198966', False, None, None, None],
#  ['28', '15.012359922756634', '45.09687189144506', False, None, None, None],
#  ['35', '16.27841761932054', '46.438687445382996', False, None, None, None],
#  ['37', '13.732407388992831', '45.42804635686404', False, None, None, None],
#  ['40', '15.975029289906558', '43.72417254491336', False, None, None, None],
#  ['42', '15.092483420763596', '44.74139058321366', False, None, None, None],
#  ['50', '15.108534783826837', '45.19990371488916', False, None, None, None],
# ...

# %%
try:
    while True:
        pass
except KeyboardInterrupt:
    print("done")
# Out:
# done

# %%
succ = list(filter(lambda r: r[3], results))

# %%
len(succ)
# Out:
# 30

# %%
# with open(f"{datetime.datetime.now().strftime('%Y_%m_%d_%H_%M')}.csv"

# %%
test_res = []

with open("results.csv") as f:
    reader = csv.reader(f, delimiter=',')
    next(reader)    # skip header
    for row in reader:
        test_res.append(row)

# %%
test_res
# Out:
# [[],
#  ['5', '16.640731441473815', '45.6776714091558', 'False', '', '', ''],
#  [],
#  ['9', '18.67219055470197', '45.601193807985766', 'False', '', '', ''],
#  [],
#  ['14', '15.969863116685294', '44.56439677506237', 'False', '', '', ''],
#  [],
#  ['20', '16.10520160056752', '43.895854173394596', 'False', '', '', ''],
#  [],
#  ['21', '13.86515235287547', '45.25963036552755', 'False', '', '', ''],
#  [],
#  ['22', '17.47708700277838', '45.158666472198966', 'False', '', '', ''],
#  [],
#  ['28', '15.012359922756634', '45.09687189144506', 'False', '', '', ''],
#  [],
#  ['35', '16.27841761932054', '46.438687445382996', 'False', '', '', ''],
#  [],
#  ['37', '13.732407388992831', '45.42804635686404', 'False', '', '', ''],
#  [],
#  ['40', '15.975029289906558', '43.72417254491336', 'False', '', '', ''],
#  [],
#  ['42',
#   '15.092483420763596',
#   '44.74139058321366',
#   'True',
#   '15.0936111',
#   '44.7411111',
# ...
